# %%
Lbs=324
Kg=324/2.2
M=2.16
C=299792458
JShaq = Kg*C**2
T=M/C

# %%
def UnitConverter(Num, Un, Kg,Met, M,T, JShaq, K):
    if Un == "m" or Un== "pc" or Un== "ly":
        Z= "in length"
    elif Un == "kg" or Un == "sm":
        Z="heavy"
    elif Un == "j" or Un == "ev":
        Z="strong"
    elif Un == "s":
        Z="long"
    if Met >= 1000 and Met < 1000000:
        N=Met/1000
        W="KiloShaqs"
        U="KiloShaq Seasons"
    if Met >= 1000000 and Met < 1000000000:
        N=Met/1000000
        W="MegaShaqs"
        U="MegaShaq Seasons"
    if Met >= 1000000000 and Met < 1000000000000:
        N=Met/1000000000
        W="GigaShaqs"
        U="GigaShaq Seasons"
    if Met >= 1000000000000 and Met < 1000000000000000:
        N=Met/1000000000000
        W="TeraShaqs"
        U="TeraShaq Seasons"
    if Met >= 1000000000000000 and Met < 1000000000000000000:
        N=Met/1000000000000000
        W="PetaShaqs"
        U="PetaShaq Seasons"
    if Met >= 1000000000000000000 and Met < 1000000000000000000000:
        N=Met/1000000000000000000
        W="ExaShaqs"
        U="ExaShaq Seasons"
    if Met >= 1000000000000000000000 and Met < 1000000000000000000000000:
        N=Met/1000000000000000000000
        W="ZettaShaqs"
        U="ZettaShaq Seasons"
    if Met >= 1000000000000000000000000 and Met < 1000000000000000000000000000:
        N=Met/1000000000000000000000000
        W="YottaShaqs"
        U="YottaShaq Seasons"
    if Met >= 1000000000000000000000000000 and Met < 1000000000000000000000000000000:
        N=Met/1000000000000000000000000000
        W="BrontoShaqs"
        U="BrontoShaq Seasons"
    if Met >= 1000000000000000000000000000000:
        N=Met/1000000000000000000000000000000
        W="GeopShaqs"
        U="GeopShaq Seasons"
    if Met >=0.001 and Met <=1:
        N=Met/0.001
        W="MilliShaqs"
        U="MilliShaq Seasons"
    if Met <=0.001 and Met >=0.000001:
        N=Met/0.000001
        W="MicroShaqs"
        U="MicroShaq Seasons"
    if Met <=0.000001 and Met >=0.000000001:
        N=Met/0.000000001
        W="NanoShaqs"
        U="NanoShaq Seasons"
    if Met <=0.000000001 and Met >=0.000000000001:
        N=Met/0.000000000001
        W="PicoShaqs"
        U="PicoShaq Seasons"
    if Met <=0.000000000001 and Met >=0.000000000000001:
        N-Met/.000000000000001
        W="FemtoShaqs"
        U="FemtoShaq Seasons"
    if Met <=0.000000000000001 and Met >=0.000000000000000001:
        N=Met/0.000000000000000001
        W="AttoShaqs"
        U="AttoShaq Seasons"
    if Met <=0.000000000000000001 and Met >=0.000000000000000000001:
        N=Met/0.000000000000000000001
        W="ZeptoShaqs"
        U="ZeptoShaq Seasons"
    if Met <=0.000000000000000000001 and Met >=0.000000000000000000000001:
        N=Met/0.000000000000000000000001
        W="YoctoShaqs"
        U="YoctoShaq Seasons"
    if Met <=0.000000000000000000000001 and Met >=0.000000000000000000000000001:
        N=Met/0.000000000000000000000000001
        W="RontoShaqs"
        U="RontoShaq Seasons"
    if Met <=0.000000000000000000000000001:
        N=Met/0.000000000000000000000000001
        W="QuectoShaqs"
        U="QuectoShaq Seasons"
    if K==1:
        print("That's " + str(N) +" " +  W + " " + Z)
    if K==2:
        print("That's " + str(N) +" " +  U + " " + Z)

# %%
def Sha(Num, Un, Kg, M,T, JShaq):
    if Un == "m":
        Met=Num/M
    if Un == "kg":
        Met=Num/Kg
    if Un == "sm":
        Met=(Num*(1.988416*10**30))/Kg
    if Un == "ly":
        Met=(Num*9460730472580800)/M
    if Un == "pc":
        Met=(Num*30856775814913673)/M
    if Un == "j":
        Met=Num/JShaq
    if Un == "ev":
        Met=(Num*1.60218*10**-19)/JShaq
    if Un == "s":
        Met=(Num/T)
    if Un == "m" or Un == "ly" or Un == "pc":
        print("The object you desire is " + str(Met) + "Shaqs in length")
    elif Un == "kg" or Un == "sm":
        print("The object you desire is " + str(Met) + " Shaqs heavy")
    elif Un == "j" or Un == "ev":
        print("The signal you desire is " + str(Met) + " Shaqs strong")
    elif Un == "s":
        print("The time you desire is " + str(Met) + " Shaqs long")
        print("That's " + str(Num/(19*365*24*60*60)) + " Shaq Seasons (Length of a Shaq Career)")
    else:
        print("That boy just ain't right")
    if Met >= 1000 or Met <= 0.001:
        while True:
            Unit = input("Do you want that simplified chief (y/n) ")
            if Unit == "y" or Unit == "Y":
                if Un == 's':
                    K=1
                    UnitConverter(Num, Un, Kg, Met, M, T,JShaq, K)
                    K=2
                    UnitConverter(Num, Un, Kg, (Num/(19*365*24*60*60)), M, T,JShaq, K)
                    break
                if Un != 's':
                    K=1
                    UnitConverter(Num, Un, Kg, Met, M, T,JShaq, K)
                    break
            elif Unit == "n" or Unit == "N":
                print("You chillin, genie-us")
                break
            else:
                print("also also nope")
                continue

# %%
while True:
    try:
        Sci=input("A log10 for you today good sir? (y/n) ")
        if Sci == "y" or Sci == "Y":
            Num=float(input("Input Number for Shaqification: "))
            Exp=int(input("How many log10s we looking at man/woman/child/rock/mineral/vegetable? "))
            Num = Num*10**Exp
            break
        if Sci == "n" or Sci == "N":
            Num=float(input("Input Number for Shaqification: "))
            break
        else:
            print("nope")
            continue
    except ValueError or OverflowError:
        print("also nope")
        continue
while True:
    Un = input("Input Unit for Shaqification: ")
    if Un== "m" or Un== "kg" or Un== "sm" or Un== "ly" or Un== "pc" or Un== "j" or Un== "ev" or Un== "s":
        break
    else:
        print("That unit just ain't right, try m, kg, sm, ly, pc, j, ev, or s")
        continue
Sha(Num, Un, Kg, M,T, JShaq)
# Out:
# The time you desire is 2.6231840074999997e+25 Shaqs long
# That's 315428983.41744775 Shaq Seasons (Length of a Shaq Career)
# That's 26.231840074999997 YottaShaqs long
# That's 315.42898341744774 MegaShaq Seasons long
